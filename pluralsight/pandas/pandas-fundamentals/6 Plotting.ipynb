# %%
import pandas as pd
import os

# %%
df = pd.read_pickle(os.path.join('data', 'artwork_data.pickle'))

# %%
# Simplest default plot
acquisition_years = df.groupby('acquisitionYear').size()
acquisition_years
# Out:
# acquisitionYear
# 1823.0       1
# 1824.0       2
# 1826.0       4
# 1827.0       1
# 1828.0       3
#           ...
# 2009.0    1364
# 2010.0     392
# 2011.0     320
# 2012.0     514
# 2013.0     458
# Length: 178, dtype: int64

# %%
acquisition_years.plot()
# Out:
# <AxesSubplot:xlabel='acquisitionYear'>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import rcParams

# %%
rcParams.update({'figure.autolayout': True, 'axes.titlepad': 20})

# %%
fig = plt.figure()
subplot = fig.add_subplot(1, 1, 1)
acquisition_years.plot(ax=subplot)
# Out:
# <AxesSubplot:xlabel='acquisitionYear'>

# %%
# Add axis labels
fig = plt.figure()
subplot = fig.add_subplot(1, 1, 1)
subplot.set_xlabel("Acquisition Year")
subplot.set_ylabel("Artworks Acquired")
acquisition_years.plot(ax=subplot)
# Out:
# <AxesSubplot:xlabel='acquisitionYear', ylabel='Artworks Acquired'>

# %%
# Increase ticks granularity
fig = plt.figure()
subplot = fig.add_subplot(1, 1, 1)
subplot.set_xlabel("Acquisition Year")
subplot.set_ylabel("Artworks Acquired")
subplot.locator_params(nbins=40, axis='x')
acquisition_years.plot(ax=subplot)
# Out:
# <AxesSubplot:xlabel='acquisitionYear', ylabel='Artworks Acquired'>

# %%
# Rotate X ticks
fig = plt.figure()
subplot = fig.add_subplot(1, 1, 1)
subplot.set_xlabel("Acquisition Year")
subplot.set_ylabel("Artworks Acquired")
subplot.locator_params(nbins=40, axis='x')
acquisition_years.plot(ax=subplot, rot=45)
# Out:
# <AxesSubplot:xlabel='acquisitionYear', ylabel='Artworks Acquired'>

# %%
# Add log scale
fig = plt.figure()
subplot = fig.add_subplot(1, 1, 1)
subplot.set_xlabel("Acquisition Year")
subplot.set_ylabel("Artworks Acquired")
subplot.locator_params(nbins=40, axis='x')
acquisition_years.plot(ax=subplot, rot=45, logy=True)
# Out:
# <AxesSubplot:xlabel='acquisitionYear', ylabel='Artworks Acquired'>

# %%
# Add grid
fig = plt.figure()
subplot = fig.add_subplot(1, 1, 1)
subplot.set_xlabel("Acquisition Year")
subplot.set_ylabel("Artworks Acquired")
subplot.locator_params(nbins=40, axis='x')
acquisition_years.plot(ax=subplot, rot=45, logy=True, grid=True)
# Out:
# <AxesSubplot:xlabel='acquisitionYear', ylabel='Artworks Acquired'>

# %%
# Set fonts
title_font = {
    'family': 'source sans pro',
    'color':  'darkblue',
    'weight': 'normal',
    'size': 20,
}
labels_font = {
    'family': 'consolas',
    'color':  'darkred',
    'weight': 'normal',
    'size': 16,
}

fig = plt.figure()
subplot = fig.add_subplot(1, 1, 1)
subplot.set_xlabel("Acquisition Year", fontdict=labels_font, labelpad=10)
subplot.set_ylabel("Artworks Acquired", fontdict=labels_font)
subplot.locator_params(nbins=40, axis='x')
subplot.set_title("Tate Gallery Acquisitions", fontdict=title_font)
acquisition_years.plot(ax=subplot, rot=45, logy=True, grid=True)
# Out:
# <AxesSubplot:title={'center':'Tate Gallery Acquisitions'}, xlabel='acquisitionYear', ylabel='Artworks Acquired'>
# findfont: Font family ['source sans pro'] not found. Falling back to DejaVu Sans.

# %%
# Save to files
fig.savefig(os.path.join('data', 'plot.png'))
fig.savefig(os.path.join('data', 'plot.svg'), format='svg')
